# %% [markdown]
# ### Import necessary libraries and packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
from keras.preprocessing import image
#from tensorflow.keras.utils import img_to_array
from keras.utils import load_img, img_to_array
import tensorflow as tf
import seaborn as sns
import cv2
from tensorflow.keras import layers, models

import csv
import re

from sklearn.model_selection import cross_val_score, StratifiedKFold,cross_validate
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, accuracy_score, roc_curve, auc,confusion_matrix,classification_report


# import json

# %% [markdown]
# ### Load the excel sheet and CESM image location - to load the dataset and labels to array

# %%
#mycsv = csv.reader(open("C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD.csv"))
# df = pd.read_excel("C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD_train.xlsx")
df = pd.read_excel("C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD.xlsx")
#df = pd.read_excel("C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD-CESM-Train.xlsx")
#df

from os.path import exists
patientID=[]
y_train = []

### pathh for the subtracted energy images and path for the low energy images
pathh='C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD-CESM\\Subtracted images of CDD-CESM\\'
path='C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD-CESM\\Low energy images of CDD-CESM\\'

SIZE= 224

train_images = []
train_labels = []
train_dhe=[]

# %% [markdown]
# ### Functions for the data augmentation - flip, translation, and rotation

# %%
def flip_image(image, direction='vertical'):
    """
    Flip the input image vertically or horizontally.

    Parameters:
    - image: Input image as a NumPy array.
    - direction: Direction of flipping, either 'vertical' or 'horizontal'.
                 Default is 'vertical'.

    Returns:
    - Flipped image as a NumPy array.
    """

    # Perform vertical flipping
    if direction == 'vertical':
        flipped_image = cv2.flip(image, 0)
    # Perform horizontal flipping
    elif direction == 'horizontal':
        flipped_image = cv2.flip(image, 1)
    else:
        raise ValueError("Invalid direction. Choose either 'vertical' or 'horizontal'.")

    return flipped_image

# %%
def translate_image(image, dx, dy):
    """
    Apply translation (shifting) augmentation to a single image.
    
    Args:
    - image: Input image (numpy array).
    - dx: Horizontal shift distance (in pixels).
    - dy: Vertical shift distance (in pixels).
    
    Returns:
    - Translated image (numpy array).
    """
    # Define translation matrix
    M = np.float32([[1, 0, dx], [0, 1, dy]])
    # Apply translation to the image
    translated_image = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))
    return translated_image

# %%
def rotate_image(image, angle):
    """
    Rotate an image by a given angle.

    Args:
        image (numpy.ndarray): Input image.
        angle (float): Rotation angle in degrees.

    Returns:
        numpy.ndarray: Rotated image.
    """
    # Get image dimensions
    height, width = image.shape[:2]
    # Calculate rotation matrix
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
    # Apply rotation to image
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

# %% [markdown]
# ### Loading the dataset (only birads 4 category) and labels

# %%
# loop to each row(i.e. each patients instances) then:
#    select only the rows with BI-RADS 4 category 
#    check if the image name of the the selected rows existing in the folder (path)
#    load the image , if it exists then preprocess
#    ptherwise skip to the next row



for index, row in df.iterrows():
    if row["BIRADS"]  == 4 or row["BIRADS"]  == "4$2" or row["BIRADS"]  == "4$3" or row["BIRADS"]  == "4"  :
        if exists(path + str(row["Image_name"]) + ".jpg") == False:
            continue

        y_train.append(row["Pathology Classification/ Follow up"])
        patientID.append(row["Image_name"])


        img = cv2.imread(path + str(row["Image_name"]) + ".jpg", cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE,SIZE))

        img = img_to_array(img)
        img = img.astype(np.uint8)
        rt = rotate_image(img, 180)
        
        
        ###To have a balance dataset apply vertical and horizontal flippings as well as translation to the dataset
        if row["Pathology Classification/ Follow up"] == "Benign" or row["Pathology Classification/ Follow up"] == 'Normal':
            vf = flip_image(img, direction='vertical')
            hf = flip_image(img, direction='horizontal')
            ti = translate_image(img, dx=20, dy=-10)
            ti2 = translate_image(rt, dx=-10, dy=20)
            

            train_images.append(vf)
            train_labels.append(row["Pathology Classification/ Follow up"])

# #             train_images.append(df)
# #             train_labels.append(row["Pathology Classification/ Follow up"])
            
            train_images.append(hf)
            train_labels.append(row["Pathology Classification/ Follow up"])
            
            train_images.append(ti)
            train_labels.append(row["Pathology Classification/ Follow up"])
            
            train_images.append(ti2)
            train_labels.append(row["Pathology Classification/ Follow up"])  
            
#             train_images.append(rt)
#             train_labels.append(row["Pathology Classification/ Follow up"])

#             fig,ax=plt.subplots(nrows=1, ncols=4, figsize=(10,3.5))
#             ax[0].imshow(img)
#             ax[0].set_title('Orignal')
#             ax[0].axis('off')


#             ax[1].imshow(result)
#             ax[1].set_title('DHE')
#             ax[1].axis('off')

#             ax[1].imshow(CLAHE_img)
#             ax[1].set_title('CLAHE')
#             ax[1].axis('off')


#             ax[2].imshow(hf)
#             ax[2].set_title('Horizontal')
#             ax[2].axis('off')

#             ax[3].imshow(vf)
#             ax[3].set_title('Vertical')
#             ax[3].axis('off')



        #except:
        #break
        #img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        #train_dhe.append(result)
        train_images.append(CLAHE_img)
        train_labels.append(row["Pathology Classification/ Follow up"])


        train_images.append(rt)
        train_labels.append(row["Pathology Classification/ Follow up"])
   
#     if index==328:
#         break

# %%
### just to confirm the number of instances for each image

from collections import Counter

# Count the unique instances in y_train
y_train_counter = Counter(train_labels)

# Print the unique instances and their counts
for pathology, count in y_train_counter.items():
    print(f"{pathology}: {count}")
# Out:
# Malignant: 306
# Benign: 234
# Normal: 6

# %% [markdown]
# ### Repeat the same process for the subtracted energy images

# %%
# df = pd.read_excel("C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD_train.xlsx")
df = pd.read_excel("C:\\Users\\S00243011\\OneDrive - Atlantic TU\\CDD-CESM\\CDD.xlsx")
for index, row in df.iterrows():
    if row["BIRADS"]  == 4 or row["BIRADS"]  == "4$2" or row["BIRADS"]  == "4$3" or row["BIRADS"]  == "4"  :
        #print(row["Right Pathology"])
        if exists(pathh + str(row["Image_name"]) + ".jpg") == False:
           # print(str(row["Image_name"]) + ".jpg")
            continue

        y_train.append(row["Pathology Classification/ Follow up"])
        patientID.append(row["Image_name"])


        img = cv2.imread(pathh + str(row["Image_name"]) + ".jpg", cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE,SIZE))

        img = img_to_array(img)

        img = img.astype(np.uint8)
        

        rt = rotate_image(img, 180)
        
        if row["Pathology Classification/ Follow up"] == "Benign" or row["Pathology Classification/ Follow up"] == 'Normal':
            vf = flip_image(img, direction='vertical')
            hf = flip_image(img, direction='horizontal')
            ti = translate_image(img, dx=20, dy=-10)
            ti2 = translate_image(rt, dx=-10, dy=20)
            

            train_images.append(vf)
            train_labels.append(row["Pathology Classification/ Follow up"])

# #             train_images.append(df)
# #             train_labels.append(row["Pathology Classification/ Follow up"])

            train_images.append(hf)
#             train_images.append(rt)
            train_labels.append(row["Pathology Classification/ Follow up"])
        
            train_images.append(ti)
            train_labels.append(row["Pathology Classification/ Follow up"])        
            
            train_images.append(ti2)
            train_labels.append(row["Pathology Classification/ Follow up"])  
#             train_images.append(rt)
#             train_labels.append(row["Pathology Classification/ Follow up"])

#             fig,ax=plt.subplots(nrows=1, ncols=4, figsize=(10,3.5))
#             ax[0].imshow(img)
#             ax[0].set_title('Orignal')
#             ax[0].axis('off')


#             ax[1].imshow(result)
#             ax[1].set_title('DHE')
#             ax[1].axis('off')

#             ax[1].imshow(CLAHE_img)
#             ax[1].set_title('CLAHE')
#             ax[1].axis('off')


#             ax[2].imshow(hf)
#             ax[2].set_title('Horizontal')
#             ax[2].axis('off')

#             ax[3].imshow(vf)
#             ax[3].set_title('Vertical')
#             ax[3].axis('off')



        #except:
        #break
        #img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        #train_dhe.append(result)
        train_images.append(CLAHE_img)
        train_labels.append(row["Pathology Classification/ Follow up"])

#         train_images.append(vf)
#         train_labels.append(row["Pathology Classification/ Follow up"])

#         train_images.append(hf)
#         train_labels.append(row["Pathology Classification/ Follow up"])

        train_images.append(rt)
        train_labels.append(row["Pathology Classification/ Follow up"])
   
#     if index==328:
#         break

# %%
### convert normal instances to benign - so binary classification benign/malignant

for i in range(len(train_labels)):
    # Check if the current element is 'n'
    if train_labels[i] == 'Normal':
        # If it is, replace it with 'x'
        train_labels[i] = 'Benign'



### convert the image and label array to numpy array
train_images=np.array(train_images)
train_images.shape

train_labels=np.array(train_labels)
#train_labels.shape

# %%
## count the number instances

from collections import Counter

# Count the unique instances in y_train
y_train_counter = Counter(train_labels)

# Print the unique instances and their counts
for pathology, count in y_train_counter.items():
    print(f"{pathology}: {count}")
# Out:
# Malignant: 490
# Benign: 444

# %%
## hot encode the labels - benign - 0, malignant- 1

train_labels=np.array(train_labels)
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(train_labels)
train_labels= le.transform(train_labels)
train_labels.shape
# Out:
# (934,)

# %%
## plot the distribution of the dataset instances

sns.countplot(x=train_labels)

# %%
## convert the classes to categorical values

from tensorflow.keras.utils import to_categorical
from keras.utils import to_categorical

# Assuming your labels are stored in a numpy array called 'labels'
num_classes = 2  # Number of classes
train_labels = to_categorical(train_labels, num_classes)

# %%
### split the dataset to training and test sets

from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(train_images, train_labels, 
                                                    test_size = 0.20, random_state = 10)
print(x_train.shape, y_val.shape)
# Out:
# (747, 224, 224, 3) (187, 2)

# %%
x_train = x_train / 255.0 #normalizing images
x_val = x_val / 255.0

# %% [markdown]
# ### Model development and traning

# %%
### import baseline model for feature extraction - this work used MobileNet

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
# from tensorflow.keras.applications.xception import Xception, preprocess_input
from tensorflow.keras.applications import MobileNetV3Large
#from tensorflow.keras.applications import SqueezeNet
#from tensorflow.keras.applications import ShuffleNet
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import NASNetMobile


from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, GlobalMaxPooling2D,AveragePooling2D,Conv2D,MaxPooling2D,Concatenate,Activation,Multiply
from tensorflow.keras import backend as K

# %%
def cbam_block(inputs, reduction_ratio=0.5):
    # Channel attention
    
    
    channels = inputs.shape[-1]
    avg_pool = layers.GlobalAveragePooling2D()(inputs)
    max_pool = layers.GlobalMaxPooling2D()(inputs)
    shared_layer_1 = layers.Dense(units=int(channels * reduction_ratio), activation='relu', use_bias=True)
    shared_layer_2 = layers.Dense(units=channels, activation='relu', use_bias=True)
    avg_pool = shared_layer_1(avg_pool)
    avg_pool = shared_layer_2(avg_pool)
    max_pool = shared_layer_1(max_pool)
    max_pool = shared_layer_2(max_pool)
    attention = layers.Add()([avg_pool, max_pool])
    attention = layers.Activation('sigmoid')(attention)
    attention = layers.Reshape((1, 1, channels))(attention)
    scaled_inputs = layers.Multiply()([inputs, attention])

    
    
    
    # Spatial attention
#     squeeze = layers.Conv2D(filters=1, kernel_size=1, activation='sigmoid', use_bias=False)(scaled_inputs)
# #     squeeze = layers.Conv2D(filters=1, kernel_size=1, activation='sigmoid', use_bias=False)(inputs)
# #     expanded_inputs = layers.Multiply()([inputs, squeeze])
#     expanded_inputs = layers.Multiply()([scaled_inputs, squeeze])
    
    
#     scaled_inputs = inputs
    cap = AveragePooling2D(pool_size=(inputs.shape[1], inputs.shape[2]))(scaled_inputs)
    cap = Conv2D(1, (1, 1), activation='relu')(cap)
    
    # Apply cross-channel max pooling (CMP)
    cmp = MaxPooling2D(pool_size=(inputs.shape[1], inputs.shape[2]))(scaled_inputs)
    cmp = Conv2D(1, (1, 1), activation='relu')(cmp)
    
    # Concatenate feature maps
    concatenated = Concatenate(axis=-1)([cap, cmp])
    
    # Apply ReLU activation
    fused = Activation('relu')(concatenated)
    
    # Apply 1x1 convolution
    weights = Conv2D(1, (1, 1), activation='sigmoid')(fused)
    
    # Element-wise multiplication with input features
    attended_inputs = Multiply()([scaled_inputs, weights])
    
    return attended_inputs

#     return scaled_inputs
#     return expanded_inputs


def Mobil_CBAM():
    input_shape = (224, 224, 3)

    # Create the ResNet50 model
#     base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     base_model = NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Add the CBAM attention mechanism
    x = base_model.output
    x = cbam_block(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(units=2, activation='sigmoid')(x)

    # Combine the ResNet50 model and the attention mechanism
    model = models.Model(inputs=base_model.input, outputs=x, name='Mobil_CBAM')

    return model


model = Mobil_CBAM()
model.summary()
# Out:
# Model: "Mobil_CBAM"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 32  128         ['conv1[0][0]']
#                                 )
#
#  conv1_relu (ReLU)              (None, 112, 112, 32  0           ['conv1_bn[0][0]']
#                                 )
#
#  conv_dw_1 (DepthwiseConv2D)    (None, 112, 112, 32  288         ['conv1_relu[0][0]']
#                                 )
#
#  conv_dw_1_bn (BatchNormalizati  (None, 112, 112, 32  128        ['conv_dw_1[0][0]']
#  on)                            )
#
#  conv_dw_1_relu (ReLU)          (None, 112, 112, 32  0           ['conv_dw_1_bn[0][0]']
#                                 )
#
#  conv_pw_1 (Conv2D)             (None, 112, 112, 64  2048        ['conv_dw_1_relu[0][0]']
#                                 )
#
#  conv_pw_1_bn (BatchNormalizati  (None, 112, 112, 64  256        ['conv_pw_1[0][0]']
#  on)                            )
#
#  conv_pw_1_relu (ReLU)          (None, 112, 112, 64  0           ['conv_pw_1_bn[0][0]']
#                                 )
#
#  conv_pad_2 (ZeroPadding2D)     (None, 113, 113, 64  0           ['conv_pw_1_relu[0][0]']
#                                 )
#
#  conv_dw_2 (DepthwiseConv2D)    (None, 56, 56, 64)   576         ['conv_pad_2[0][0]']
#
#  conv_dw_2_bn (BatchNormalizati  (None, 56, 56, 64)  256         ['conv_dw_2[0][0]']
#  on)
#
#  conv_dw_2_relu (ReLU)          (None, 56, 56, 64)   0           ['conv_dw_2_bn[0][0]']
#
#  conv_pw_2 (Conv2D)             (None, 56, 56, 128)  8192        ['conv_dw_2_relu[0][0]']
#
#  conv_pw_2_bn (BatchNormalizati  (None, 56, 56, 128)  512        ['conv_pw_2[0][0]']
#  on)
#
#  conv_pw_2_relu (ReLU)          (None, 56, 56, 128)  0           ['conv_pw_2_bn[0][0]']
#
#  conv_dw_3 (DepthwiseConv2D)    (None, 56, 56, 128)  1152        ['conv_pw_2_relu[0][0]']
#
#  conv_dw_3_bn (BatchNormalizati  (None, 56, 56, 128)  512        ['conv_dw_3[0][0]']
#  on)
#
#  conv_dw_3_relu (ReLU)          (None, 56, 56, 128)  0           ['conv_dw_3_bn[0][0]']
#
#  conv_pw_3 (Conv2D)             (None, 56, 56, 128)  16384       ['conv_dw_3_relu[0][0]']
#
#  conv_pw_3_bn (BatchNormalizati  (None, 56, 56, 128)  512        ['conv_pw_3[0][0]']
#  on)
#
#  conv_pw_3_relu (ReLU)          (None, 56, 56, 128)  0           ['conv_pw_3_bn[0][0]']
#
#  conv_pad_4 (ZeroPadding2D)     (None, 57, 57, 128)  0           ['conv_pw_3_relu[0][0]']
#
#  conv_dw_4 (DepthwiseConv2D)    (None, 28, 28, 128)  1152        ['conv_pad_4[0][0]']
#
#  conv_dw_4_bn (BatchNormalizati  (None, 28, 28, 128)  512        ['conv_dw_4[0][0]']
#  on)
#
#  conv_dw_4_relu (ReLU)          (None, 28, 28, 128)  0           ['conv_dw_4_bn[0][0]']
#
#  conv_pw_4 (Conv2D)             (None, 28, 28, 256)  32768       ['conv_dw_4_relu[0][0]']
#
#  conv_pw_4_bn (BatchNormalizati  (None, 28, 28, 256)  1024       ['conv_pw_4[0][0]']
#  on)
#
#  conv_pw_4_relu (ReLU)          (None, 28, 28, 256)  0           ['conv_pw_4_bn[0][0]']
#
#  conv_dw_5 (DepthwiseConv2D)    (None, 28, 28, 256)  2304        ['conv_pw_4_relu[0][0]']
#
#  conv_dw_5_bn (BatchNormalizati  (None, 28, 28, 256)  1024       ['conv_dw_5[0][0]']
#  on)
#
#  conv_dw_5_relu (ReLU)          (None, 28, 28, 256)  0           ['conv_dw_5_bn[0][0]']
#
#  conv_pw_5 (Conv2D)             (None, 28, 28, 256)  65536       ['conv_dw_5_relu[0][0]']
#
#  conv_pw_5_bn (BatchNormalizati  (None, 28, 28, 256)  1024       ['conv_pw_5[0][0]']
#  on)
#
#  conv_pw_5_relu (ReLU)          (None, 28, 28, 256)  0           ['conv_pw_5_bn[0][0]']
#
#  conv_pad_6 (ZeroPadding2D)     (None, 29, 29, 256)  0           ['conv_pw_5_relu[0][0]']
#
#  conv_dw_6 (DepthwiseConv2D)    (None, 14, 14, 256)  2304        ['conv_pad_6[0][0]']
#
#  conv_dw_6_bn (BatchNormalizati  (None, 14, 14, 256)  1024       ['conv_dw_6[0][0]']
#  on)
#
#  conv_dw_6_relu (ReLU)          (None, 14, 14, 256)  0           ['conv_dw_6_bn[0][0]']
#
#  conv_pw_6 (Conv2D)             (None, 14, 14, 512)  131072      ['conv_dw_6_relu[0][0]']
#
#  conv_pw_6_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_6[0][0]']
#  on)
#
#  conv_pw_6_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_6_bn[0][0]']
#
#  conv_dw_7 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_6_relu[0][0]']
#
#  conv_dw_7_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_7[0][0]']
#  on)
#
#  conv_dw_7_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_7_bn[0][0]']
#
#  conv_pw_7 (Conv2D)             (None, 14, 14, 512)  262144      ['conv_dw_7_relu[0][0]']
#
#  conv_pw_7_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_7[0][0]']
#  on)
#
#  conv_pw_7_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_7_bn[0][0]']
#
#  conv_dw_8 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_7_relu[0][0]']
#
#  conv_dw_8_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_8[0][0]']
#  on)
#
#  conv_dw_8_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_8_bn[0][0]']
#
#  conv_pw_8 (Conv2D)             (None, 14, 14, 512)  262144      ['conv_dw_8_relu[0][0]']
#
#  conv_pw_8_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_8[0][0]']
#  on)
#
#  conv_pw_8_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_8_bn[0][0]']
#
#  conv_dw_9 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_8_relu[0][0]']
#
#  conv_dw_9_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_9[0][0]']
#  on)
#
#  conv_dw_9_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_9_bn[0][0]']
#
#  conv_pw_9 (Conv2D)             (None, 14, 14, 512)  262144      ['conv_dw_9_relu[0][0]']
#
#  conv_pw_9_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_9[0][0]']
#  on)
#
#  conv_pw_9_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_9_bn[0][0]']
#
#  conv_dw_10 (DepthwiseConv2D)   (None, 14, 14, 512)  4608        ['conv_pw_9_relu[0][0]']
#
#  conv_dw_10_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_dw_10[0][0]']
#  ion)
#
#  conv_dw_10_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_dw_10_bn[0][0]']
#
#  conv_pw_10 (Conv2D)            (None, 14, 14, 512)  262144      ['conv_dw_10_relu[0][0]']
#
#  conv_pw_10_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_pw_10[0][0]']
#  ion)
#
#  conv_pw_10_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_pw_10_bn[0][0]']
#
#  conv_dw_11 (DepthwiseConv2D)   (None, 14, 14, 512)  4608        ['conv_pw_10_relu[0][0]']
#
#  conv_dw_11_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_dw_11[0][0]']
#  ion)
#
#  conv_dw_11_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_dw_11_bn[0][0]']
#
#  conv_pw_11 (Conv2D)            (None, 14, 14, 512)  262144      ['conv_dw_11_relu[0][0]']
#
#  conv_pw_11_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_pw_11[0][0]']
#  ion)
#
#  conv_pw_11_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_pw_11_bn[0][0]']
#
#  conv_pad_12 (ZeroPadding2D)    (None, 15, 15, 512)  0           ['conv_pw_11_relu[0][0]']
#
#  conv_dw_12 (DepthwiseConv2D)   (None, 7, 7, 512)    4608        ['conv_pad_12[0][0]']
#
#  conv_dw_12_bn (BatchNormalizat  (None, 7, 7, 512)   2048        ['conv_dw_12[0][0]']
#  ion)
#
#  conv_dw_12_relu (ReLU)         (None, 7, 7, 512)    0           ['conv_dw_12_bn[0][0]']
#
#  conv_pw_12 (Conv2D)            (None, 7, 7, 1024)   524288      ['conv_dw_12_relu[0][0]']
#
#  conv_pw_12_bn (BatchNormalizat  (None, 7, 7, 1024)  4096        ['conv_pw_12[0][0]']
#  ion)
#
#  conv_pw_12_relu (ReLU)         (None, 7, 7, 1024)   0           ['conv_pw_12_bn[0][0]']
#
#  conv_dw_13 (DepthwiseConv2D)   (None, 7, 7, 1024)   9216        ['conv_pw_12_relu[0][0]']
#
#  conv_dw_13_bn (BatchNormalizat  (None, 7, 7, 1024)  4096        ['conv_dw_13[0][0]']
#  ion)
#
#  conv_dw_13_relu (ReLU)         (None, 7, 7, 1024)   0           ['conv_dw_13_bn[0][0]']
#
#  conv_pw_13 (Conv2D)            (None, 7, 7, 1024)   1048576     ['conv_dw_13_relu[0][0]']
#
#  conv_pw_13_bn (BatchNormalizat  (None, 7, 7, 1024)  4096        ['conv_pw_13[0][0]']
#  ion)
#
#  conv_pw_13_relu (ReLU)         (None, 7, 7, 1024)   0           ['conv_pw_13_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['conv_pw_13_relu[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 1024)        0           ['conv_pw_13_relu[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 512)          524800      ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         525312      ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  add (Add)                      (None, 1024)         0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  activation (Activation)        (None, 1024)         0           ['add[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 1024)   0           ['activation[0][0]']
#
#  multiply (Multiply)            (None, 7, 7, 1024)   0           ['conv_pw_13_relu[0][0]',
#                                                                   'reshape[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 1024)  0           ['multiply[0][0]']
#  ing2D)
#
#  max_pooling2d (MaxPooling2D)   (None, 1, 1, 1024)   0           ['multiply[0][0]']
#
#  conv2d (Conv2D)                (None, 1, 1, 1)      1025        ['average_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 1, 1, 1)      1025        ['max_pooling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 1, 1, 2)      0           ['conv2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  activation_1 (Activation)      (None, 1, 1, 2)      0           ['concatenate[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 1, 1, 1)      3           ['activation_1[0][0]']
#
#  multiply_1 (Multiply)          (None, 7, 7, 1024)   0           ['multiply[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['multiply_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 2)            2050        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 4,283,079
# Trainable params: 4,261,191
# Non-trainable params: 21,888
# __________________________________________________________________________________________________

# %%
# Compile the model
from sklearn.metrics import hinge_loss
from tensorflow.keras.losses import Hinge


# model.compile(optimizer=Adam(), loss=Hinge(), metrics=['binary_accuracy'])
#model.compile(optimizer=Adam(), loss=Hinge(), metrics=['accuracy'])
#model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Model training five fold cross-validation

# %%
import time

# Lists to store running times for each fold
fold_runtimes = []


n_folds = 5 
kf = KFold(n_splits=5, shuffle=True, random_state=10)

accuracies = []
losses = []
auc_scores = []
f1_scores = []
precision_scores = []
recall_scores = []
specificity_scores = []
mean_fpr = np.linspace(0, 1, 100)
tprs = []
confusion_matrices=[]

# Initialize dictionaries to store metrics for each class across folds
class_metrics = {metric: {} for metric in ['precision', 'recall', 'f1-score', 'support', 'specificity']}


# Lists to store metrics for each fold
all_train_accuracy = []
all_val_accuracy = []
all_train_loss = []
all_val_loss = []

train_images = x_train
train_labels = y_train


for fold, (train_index, val_index) in enumerate(kf.split(train_images)):
    print(f"Training on Fold {fold + 1}...")
    start_time = time.time() 
#for train_index, val_index in kf.split(train_images):
    # Split data into training and validation sets
    X_train_fold, X_val_fold = train_images[train_index], train_images[val_index]
    y_train_fold, y_val_fold = train_labels[train_index], train_labels[val_index]
    
    # Train the model on the training data
    history = model.fit(X_train_fold, y_train_fold, epochs=40, batch_size=16,validation_data=(X_val_fold, y_val_fold), verbose=1)
    
    
    end_time = time.time()  # Record end time
    fold_runtime = end_time - start_time  # Calculate duration
    fold_runtimes.append(fold_runtime)  # Store duration for this fold
    
         # Collect training history for accuracy and loss
    train_accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    
#     train_accuracy = history.history['binary_accuracy']
#     val_accuracy = history.history['val_binary_accuracy']
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
     # Append the metrics for this fold to the lists
    all_train_accuracy.append(train_accuracy)
    all_val_accuracy.append(val_accuracy)
    all_train_loss.append(train_loss)
    all_val_loss.append(val_loss)

    
    # Evaluate the model on the test set for this fold
    test_loss, test_accuracy = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    accuracies.append(test_accuracy)
    losses.append(test_loss)
    
    
    
    # Evaluate the model on the validation data
    val_preds = model.predict(X_val_fold)
    val_acc = accuracy_score(np.argmax(y_val_fold, axis=1), np.argmax(val_preds, axis=1))
    
    
    auc_score = roc_auc_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    auc_scores.append(auc_score)
    
    f1 = f1_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    f1_scores.append(f1)
    
    precision = precision_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    precision_scores.append(precision)
    
    recall = recall_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    recall_scores.append(recall)
    
    
    cm = confusion_matrix(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    # print(cm)
    confusion_matrices.append(cm)

     # Calculate specificity
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)
    specificity_scores.append(specificity)
    

    # Generate classification report for detailed metrics
    report = classification_report(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1), output_dict=True)
    for cls, metrics in report.items():
        if cls.isdigit():  # Ensure the key is a class (digits)
            if cls not in class_metrics['precision']:
                for metric in class_metrics:
                    class_metrics[metric][cls] = []
            class_metrics['precision'][cls].append(metrics['precision'])
            class_metrics['recall'][cls].append(metrics['recall'])
            class_metrics['f1-score'][cls].append(metrics['f1-score'])
            class_metrics['support'][cls].append(metrics['support'])

    # Calculate specificity for each class and add to class metrics
    for i in range(len(cm)):
        tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fp = cm[:, i].sum() - cm[i, i]
        specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
        class_metrics['specificity'].setdefault(str(i), []).append(specificity)
        
#     # Append validation accuracy to list
#     cv_scores.append(val_acc)
    
    

    # Calculate ROC curve for this fold and interpolate it to make it smoother
    fpr, tpr, _ = roc_curve(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    tprs.append(np.interp(mean_fpr, fpr, tpr))

    # Plot the AUC-ROC curve for this fold
    #plt.plot(fpr, tpr, label=f'Fold {len(fold_scores)}')
    plt.plot(fpr, tpr, lw=1, alpha=0.7, label='Fold {} (AUC = {:.2f})'.format(fold, auc_score))
 
    
# Calculate and plot the mean ROC curve
mean_tpr = np.mean(tprs, axis=0)
mean_auc = auc(mean_fpr, mean_tpr)

# Optionally, plot the mean ROC curve
plt.plot(mean_fpr, mean_tpr, color='b', lw=2, label='Mean ROC (AUC = {:.2f})'.format(mean_auc))
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

# Optionally, configure the plot for the ROC curve
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Mean ROC Curve')
plt.legend(loc='lower right')
plt.show()
    
# # Print cross-validation scores
# print("Cross-Validation Scores:", cv_scores)
# print("Mean CV Score:", np.mean(cv_scores))
# print("Standard Deviation of CV Scores:", np.std(cv_scores))


print("Cross-validation Accuracy:", accuracies)
print("Average Accuracy:", np.mean(accuracies))
print("Std Accuracy:", np.std(accuracies))
print()
print("Cross-validation Loss:", losses)
print("Average Loss:", np.mean(losses))
print("Std Loss:", np.std(losses))
print()
print("Cross-validation AUC:", auc_scores)
print("Average AUC:", np.mean(auc_scores))
print("Std AUC:", np.std(auc_scores))
print()
print("Cross-validation F1-score:", f1_scores)
print("Average F1-score:", np.mean(f1_scores))
print("Std F1 score:", np.std(f1_scores))
print()
print("Cross-validation precision:", precision_scores)
print("Average Precision:", np.mean(precision_scores))
print("Std Precision:", np.std(precision_scores))
print()
print("Cross-validation Recall:", recall_scores)
print("Average Recall:", np.mean(recall_scores))
print("Std Recall:", np.std(recall_scores))
print()
print("Cross-validation Specificity:", specificity_scores)
print("Average Specificity:", np.mean(specificity_scores))
print("Std Specificity:", np.std(specificity_scores))
print()
print("Fold Runtimes (seconds):", fold_runtimes)
print("Average Runtime:", np.mean(fold_runtimes))
print("Standard Deviation of Runtimes:", np.std(fold_runtimes))
# Out:
# Training on Fold 1...
# Epoch 1/40
# 38/38 [==============================] - 117s 3s/step - loss: 0.6691 - accuracy: 0.5896 - val_loss: 0.7438 - val_accuracy: 0.4800
# Epoch 2/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.5374 - accuracy: 0.7253 - val_loss: 0.7593 - val_accuracy: 0.6600
# Epoch 3/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.3781 - accuracy: 0.8241 - val_loss: 3.7493 - val_accuracy: 0.4533
# Epoch 4/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.4363 - accuracy: 0.7990 - val_loss: 0.6834 - val_accuracy: 0.6667
# Epoch 5/40
# 38/38 [==============================] - 86s 2s/step - loss: 0.3156 - accuracy: 0.8476 - val_loss: 0.6183 - val_accuracy: 0.7533
# Epoch 6/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.1826 - accuracy: 0.9296 - val_loss: 0.6360 - val_accuracy: 0.7267
# Epoch 7/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.1569 - accuracy: 0.9330 - val_loss: 1.1201 - val_accuracy: 0.6800
# Epoch 9/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.1195 - accuracy: 0.9531 - val_loss: 0.6121 - val_accuracy: 0.7667
# Epoch 10/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0633 - accuracy: 0.9816 - val_loss: 0.7950 - val_accuracy: 0.7800
# Epoch 11/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0641 - accuracy: 0.9849 - val_loss: 0.6160 - val_accuracy: 0.7867
# Epoch 12/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.0817 - accuracy: 0.9682 - val_loss: 1.0485 - val_accuracy: 0.7933
# Epoch 13/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0884 - accuracy: 0.9732 - val_loss: 0.7531 - val_accuracy: 0.7867
# Epoch 14/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0755 - accuracy: 0.9698 - val_loss: 0.9055 - val_accuracy: 0.7600
# Epoch 15/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.0718 - accuracy: 0.9698 - val_loss: 1.1772 - val_accuracy: 0.7200
# Epoch 16/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0505 - accuracy: 0.9832 - val_loss: 1.0489 - val_accuracy: 0.7400
# Epoch 17/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0766 - accuracy: 0.9749 - val_loss: 0.6073 - val_accuracy: 0.8133
# Epoch 18/40
# 38/38 [==============================] - 86s 2s/step - loss: 0.0390 - accuracy: 0.9916 - val_loss: 1.2090 - val_accuracy: 0.7333
# Epoch 19/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.0275 - accuracy: 0.9916 - val_loss: 1.2631 - val_accuracy: 0.7133
# Epoch 20/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0252 - accuracy: 0.9899 - val_loss: 0.9823 - val_accuracy: 0.7533
# Epoch 21/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.0450 - accuracy: 0.9883 - val_loss: 1.2869 - val_accuracy: 0.7333
# Epoch 22/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0510 - accuracy: 0.9866 - val_loss: 2.0201 - val_accuracy: 0.6733
# Epoch 23/40
# 38/38 [==============================] - 86s 2s/step - loss: 0.0179 - accuracy: 0.9983 - val_loss: 0.7624 - val_accuracy: 0.8133
# Epoch 24/40
# 38/38 [==============================] - 91s 2s/step - loss: 0.0138 - accuracy: 0.9950 - val_loss: 1.1975 - val_accuracy: 0.7267
# Epoch 25/40
# 38/38 [==============================] - 93s 2s/step - loss: 0.0102 - accuracy: 0.9983 - val_loss: 0.9742 - val_accuracy: 0.7467
# Epoch 26/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.1224 - accuracy: 0.9631 - val_loss: 4.2584 - val_accuracy: 0.5733
# Epoch 27/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.1057 - accuracy: 0.9615 - val_loss: 2.0347 - val_accuracy: 0.6733
# Epoch 28/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0605 - accuracy: 0.9799 - val_loss: 0.8835 - val_accuracy: 0.7667
# Epoch 29/40
# 38/38 [==============================] - 81s 2s/step - loss: 0.0823 - accuracy: 0.9749 - val_loss: 1.1269 - val_accuracy: 0.7800
# Epoch 30/40
# 38/38 [==============================] - 90s 2s/step - loss: 0.0292 - accuracy: 0.9950 - val_loss: 0.9907 - val_accuracy: 0.7400
# Epoch 31/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 1.0948 - val_accuracy: 0.7333
# Epoch 32/40
# 38/38 [==============================] - 89s 2s/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 1.1428 - val_accuracy: 0.7133
# Epoch 33/40
# 38/38 [==============================] - 93s 2s/step - loss: 0.0305 - accuracy: 0.9933 - val_loss: 1.1237 - val_accuracy: 0.7533
# Epoch 34/40
# 38/38 [==============================] - 89s 2s/step - loss: 0.0262 - accuracy: 0.9933 - val_loss: 0.9423 - val_accuracy: 0.7467
# Epoch 35/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0573 - accuracy: 0.9782 - val_loss: 0.9519 - val_accuracy: 0.7600
# Epoch 36/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.1702 - accuracy: 0.9380 - val_loss: 0.8051 - val_accuracy: 0.7467
# Epoch 37/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0701 - accuracy: 0.9765 - val_loss: 1.0334 - val_accuracy: 0.7000
# Epoch 38/40
# 38/38 [==============================] - 81s 2s/step - loss: 0.0745 - accuracy: 0.9665 - val_loss: 0.9029 - val_accuracy: 0.7400
# Epoch 39/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.0424 - accuracy: 0.9899 - val_loss: 0.8389 - val_accuracy: 0.7733
# Epoch 40/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0655 - accuracy: 0.9883 - val_loss: 1.3290 - val_accuracy: 0.7000
# 5/5 [==============================] - 10s 328ms/step
# Training on Fold 2...
# Epoch 1/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.2497 - accuracy: 0.9012 - val_loss: 0.1143 - val_accuracy: 0.9600
# Epoch 2/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.1386 - accuracy: 0.9531 - val_loss: 0.0299 - val_accuracy: 0.9867
# Epoch 3/40
# 38/38 [==============================] - 86s 2s/step - loss: 0.0501 - accuracy: 0.9849 - val_loss: 0.1397 - val_accuracy: 0.9400
# Epoch 4/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0120 - accuracy: 0.9983 - val_loss: 0.0296 - val_accuracy: 0.9933
# Epoch 5/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0222 - accuracy: 0.9950 - val_loss: 0.0438 - val_accuracy: 0.9800
# Epoch 6/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0669 - accuracy: 0.9749 - val_loss: 0.4218 - val_accuracy: 0.8533
# Epoch 7/40
# 38/38 [==============================] - 81s 2s/step - loss: 0.0472 - accuracy: 0.9916 - val_loss: 0.0556 - val_accuracy: 0.9800
# Epoch 8/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0099 - accuracy: 0.9950 - val_loss: 0.0149 - val_accuracy: 0.9933
# Epoch 9/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0690 - val_accuracy: 0.9800
# Epoch 10/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0117 - accuracy: 0.9950 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 11/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0196 - accuracy: 0.9916 - val_loss: 0.0412 - val_accuracy: 0.9867
# Epoch 12/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0580 - val_accuracy: 0.9733
# Epoch 13/40
# 38/38 [==============================] - 77s 2s/step - loss: 0.0122 - accuracy: 0.9933 - val_loss: 0.0446 - val_accuracy: 0.9800
# Epoch 14/40
# 38/38 [==============================] - 80s 2s/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0761 - val_accuracy: 0.9800
# Epoch 15/40
# 38/38 [==============================] - 86s 2s/step - loss: 0.0467 - accuracy: 0.9816 - val_loss: 0.5367 - val_accuracy: 0.8267
# Epoch 16/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0397 - accuracy: 0.9816 - val_loss: 0.0615 - val_accuracy: 0.9667
# Epoch 17/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0210 - accuracy: 0.9950 - val_loss: 0.0429 - val_accuracy: 0.9800
# Epoch 18/40
# 38/38 [==============================] - 85s 2s/step - loss: 0.0244 - accuracy: 0.9933 - val_loss: 0.0286 - val_accuracy: 0.9933
# Epoch 19/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0263 - val_accuracy: 0.9933
# Epoch 20/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9867
# Epoch 21/40
# 38/38 [==============================] - 81s 2s/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0868 - val_accuracy: 0.9733
# Epoch 22/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.0760 - val_accuracy: 0.9800
# Epoch 23/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0295 - accuracy: 0.9883 - val_loss: 0.1231 - val_accuracy: 0.9467
# Epoch 24/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0451 - accuracy: 0.9799 - val_loss: 0.1193 - val_accuracy: 0.9600
# Epoch 25/40
# 38/38 [==============================] - 86s 2s/step - loss: 0.0329 - accuracy: 0.9899 - val_loss: 0.7636 - val_accuracy: 0.8133
# Epoch 26/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0465 - accuracy: 0.9816 - val_loss: 0.0897 - val_accuracy: 0.9467
# Epoch 27/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0328 - accuracy: 0.9899 - val_loss: 0.0496 - val_accuracy: 0.9800
# Epoch 28/40
# 38/38 [==============================] - 79s 2s/step - loss: 0.0136 - accuracy: 0.9983 - val_loss: 0.0493 - val_accuracy: 0.9733
# Epoch 29/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9933
# Epoch 30/40
# 38/38 [==============================] - 82s 2s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 0.9867
# Epoch 31/40
# 38/38 [==============================] - 84s 2s/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0555 - val_accuracy: 0.9800
# Epoch 32/40
# 38/38 [==============================] - 91s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9800
# Epoch 33/40
# 38/38 [==============================] - 89s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9867
# Epoch 34/40
# 38/38 [==============================] - 86s 2s/step - loss: 8.2380e-04 - accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 0.9800
# Epoch 35/40
# 38/38 [==============================] - 95s 3s/step - loss: 6.7038e-04 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9800
# Epoch 36/40
# 38/38 [==============================] - 139s 4s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9800
# Epoch 37/40
# 38/38 [==============================] - 99s 3s/step - loss: 6.6520e-04 - accuracy: 1.0000 - val_loss: 0.0513 - val_accuracy: 0.9800
# Epoch 38/40
# 38/38 [==============================] - 1554s 42s/step - loss: 4.2327e-04 - accuracy: 1.0000 - val_loss: 0.0527 - val_accuracy: 0.9800
# Epoch 39/40
# 38/38 [==============================] - 127s 3s/step - loss: 2.3228e-04 - accuracy: 1.0000 - val_loss: 0.0517 - val_accuracy: 0.9800
# Epoch 40/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0132 - accuracy: 0.9916 - val_loss: 0.1048 - val_accuracy: 0.9600
# 5/5 [==============================] - 2s 495ms/step
# Training on Fold 3...
# Epoch 1/40
# 38/38 [==============================] - 110s 3s/step - loss: 0.0788 - accuracy: 0.9749 - val_loss: 0.8301 - val_accuracy: 0.8054
# Epoch 2/40
# 38/38 [==============================] - 129s 3s/step - loss: 0.1383 - accuracy: 0.9532 - val_loss: 0.2637 - val_accuracy: 0.9262
# Epoch 3/40
# 38/38 [==============================] - 100s 3s/step - loss: 0.0449 - accuracy: 0.9883 - val_loss: 0.0720 - val_accuracy: 0.9732
# Epoch 4/40
# 38/38 [==============================] - 114s 3s/step - loss: 0.0299 - accuracy: 0.9883 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 5/40
# 38/38 [==============================] - 124s 3s/step - loss: 0.0385 - accuracy: 0.9849 - val_loss: 0.2940 - val_accuracy: 0.9128
# Epoch 6/40
# 38/38 [==============================] - 103s 3s/step - loss: 0.0424 - accuracy: 0.9833 - val_loss: 0.0342 - val_accuracy: 0.9866
# Epoch 7/40
# 38/38 [==============================] - 91s 2s/step - loss: 0.0363 - accuracy: 0.9950 - val_loss: 0.1577 - val_accuracy: 0.9329
# Epoch 8/40
# 38/38 [==============================] - 107s 3s/step - loss: 0.0188 - accuracy: 0.9933 - val_loss: 0.0295 - val_accuracy: 0.9933
# Epoch 9/40
# 38/38 [==============================] - 105s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 10/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 11/40
# 38/38 [==============================] - 92s 2s/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 12/40
# 38/38 [==============================] - 117s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 13/40
# 38/38 [==============================] - 113s 3s/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 14/40
# 38/38 [==============================] - 123s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 15/40
# 38/38 [==============================] - 153s 4s/step - loss: 6.4793e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 16/40
# 38/38 [==============================] - 105s 3s/step - loss: 8.1325e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 17/40
# 38/38 [==============================] - 130s 3s/step - loss: 9.7678e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 18/40
# 38/38 [==============================] - 153s 4s/step - loss: 4.1372e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 19/40
# 38/38 [==============================] - 99s 3s/step - loss: 3.1640e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 20/40
# 38/38 [==============================] - 93s 2s/step - loss: 2.3884e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 21/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 22/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0507 - val_accuracy: 0.9799
# Epoch 23/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.1155 - accuracy: 0.9548 - val_loss: 0.3962 - val_accuracy: 0.8658
# Epoch 25/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0228 - accuracy: 0.9950 - val_loss: 0.0649 - val_accuracy: 0.9732
# Epoch 26/40
# 38/38 [==============================] - 93s 2s/step - loss: 0.0122 - accuracy: 0.9950 - val_loss: 0.1832 - val_accuracy: 0.9530
# Epoch 27/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0155 - accuracy: 0.9933 - val_loss: 0.1988 - val_accuracy: 0.9597
# Epoch 28/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0102 - accuracy: 0.9983 - val_loss: 0.0531 - val_accuracy: 0.9866
# Epoch 29/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0100 - accuracy: 0.9950 - val_loss: 0.2329 - val_accuracy: 0.9396
# Epoch 30/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0913 - val_accuracy: 0.9799
# Epoch 31/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9799
# Epoch 32/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1112 - val_accuracy: 0.9799
# Epoch 33/40
# 38/38 [==============================] - 98s 3s/step - loss: 6.3890e-04 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9799
# Epoch 34/40
# 38/38 [==============================] - 99s 3s/step - loss: 4.4735e-04 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9799
# Epoch 35/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9664
# Epoch 36/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0036 - accuracy: 0.9983 - val_loss: 0.0851 - val_accuracy: 0.9597
# Epoch 37/40
# 38/38 [==============================] - 96s 3s/step - loss: 8.4591e-04 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9799
# Epoch 38/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0030 - accuracy: 0.9983 - val_loss: 0.0678 - val_accuracy: 0.9799
# Epoch 39/40
# 38/38 [==============================] - 97s 3s/step - loss: 4.7808e-04 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9933
# Epoch 40/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0022 - accuracy: 0.9983 - val_loss: 0.0656 - val_accuracy: 0.9799
# 5/5 [==============================] - 2s 299ms/step
# Training on Fold 4...
# Epoch 1/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0385 - accuracy: 0.9849 - val_loss: 0.0125 - val_accuracy: 0.9933
# Epoch 2/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.2423 - accuracy: 0.9214 - val_loss: 1.4895 - val_accuracy: 0.6846
# Epoch 3/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.1206 - accuracy: 0.9532 - val_loss: 0.0480 - val_accuracy: 0.9799
# Epoch 4/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0300 - accuracy: 0.9933 - val_loss: 0.0469 - val_accuracy: 0.9866
# Epoch 5/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.0334 - val_accuracy: 0.9866
# Epoch 6/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9866
# Epoch 7/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9866
# Epoch 8/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9866
# Epoch 9/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9866
# Epoch 10/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9866
# Epoch 11/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9866
# Epoch 12/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9933
# Epoch 13/40
# 38/38 [==============================] - 93s 2s/step - loss: 6.9936e-04 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9933
# Epoch 14/40
# 38/38 [==============================] - 95s 3s/step - loss: 3.8092e-04 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9933
# Epoch 15/40
# 38/38 [==============================] - 95s 3s/step - loss: 5.0281e-04 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9933
# Epoch 16/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9933
# Epoch 17/40
# 38/38 [==============================] - 96s 3s/step - loss: 6.9189e-04 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9933
# Epoch 18/40
# 38/38 [==============================] - 95s 2s/step - loss: 7.9945e-04 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9933
# Epoch 19/40
# 38/38 [==============================] - 95s 3s/step - loss: 2.7400e-04 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 0.9933
# Epoch 20/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 21/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0518 - accuracy: 0.9849 - val_loss: 0.1684 - val_accuracy: 0.9262
# Epoch 22/40
# 38/38 [==============================] - 99s 3s/step - loss: 0.0622 - accuracy: 0.9783 - val_loss: 1.0017 - val_accuracy: 0.7315
# Epoch 23/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0438 - accuracy: 0.9816 - val_loss: 1.2262 - val_accuracy: 0.7315
# Epoch 24/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0308 - accuracy: 0.9883 - val_loss: 0.1425 - val_accuracy: 0.9396
# Epoch 25/40
# 38/38 [==============================] - 93s 2s/step - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.1306 - val_accuracy: 0.9463
# Epoch 26/40
# 38/38 [==============================] - 93s 2s/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.1092 - val_accuracy: 0.9732
# Epoch 27/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.0662 - val_accuracy: 0.9866
# Epoch 28/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0521 - val_accuracy: 0.9866
# Epoch 29/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9866
# Epoch 31/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0033 - accuracy: 0.9983 - val_loss: 0.1207 - val_accuracy: 0.9664
# Epoch 32/40
# 38/38 [==============================] - 93s 2s/step - loss: 8.8663e-04 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9463
# Epoch 33/40
# 38/38 [==============================] - 93s 2s/step - loss: 4.1861e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9530
# Epoch 34/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9597
# Epoch 35/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9597
# Epoch 36/40
# 38/38 [==============================] - 97s 3s/step - loss: 8.0404e-04 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9664
# Epoch 37/40
# 38/38 [==============================] - 97s 3s/step - loss: 3.0480e-04 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9664
# Epoch 38/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9732
# Epoch 39/40
# 38/38 [==============================] - 96s 3s/step - loss: 2.4540e-04 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9732
# Epoch 40/40
# 38/38 [==============================] - 95s 2s/step - loss: 2.9421e-04 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9866
# 5/5 [==============================] - 2s 318ms/step
# Training on Fold 5...
# Epoch 1/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0164 - accuracy: 0.9933 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 2/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0172 - accuracy: 0.9933 - val_loss: 0.1303 - val_accuracy: 0.9732
# Epoch 3/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0144 - accuracy: 0.9933 - val_loss: 0.0180 - val_accuracy: 0.9866
# Epoch 4/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 5/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0600 - val_accuracy: 0.9799
# Epoch 6/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0968 - accuracy: 0.9682 - val_loss: 0.6920 - val_accuracy: 0.8389
# Epoch 7/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.1227 - accuracy: 0.9515 - val_loss: 0.0818 - val_accuracy: 0.9664
# Epoch 8/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0668 - accuracy: 0.9833 - val_loss: 0.0843 - val_accuracy: 0.9732
# Epoch 9/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0122 - accuracy: 0.9983 - val_loss: 0.0505 - val_accuracy: 0.9866
# Epoch 10/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9933
# Epoch 11/40
# 38/38 [==============================] - 99s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 0.9933
# Epoch 12/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 13/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 14/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 15/40
# 38/38 [==============================] - 93s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 16/40
# 38/38 [==============================] - 96s 3s/step - loss: 0.0036 - accuracy: 0.9983 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 17/40
# 38/38 [==============================] - 99s 3s/step - loss: 0.0124 - accuracy: 0.9933 - val_loss: 0.0132 - val_accuracy: 0.9933
# Epoch 18/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 19/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9933
# Epoch 20/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 21/40
# 38/38 [==============================] - 95s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 22/40
# 38/38 [==============================] - 95s 3s/step - loss: 6.9521e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 23/40
# 38/38 [==============================] - 96s 3s/step - loss: 4.8375e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 24/40
# 38/38 [==============================] - 102s 3s/step - loss: 2.3208e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 25/40
# 38/38 [==============================] - 118s 3s/step - loss: 4.6334e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 26/40
# 38/38 [==============================] - 97s 3s/step - loss: 2.0014e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 27/40
# 38/38 [==============================] - 101s 3s/step - loss: 3.1814e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 28/40
# 38/38 [==============================] - 96s 2s/step - loss: 9.8006e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 29/40
# 38/38 [==============================] - 95s 2s/step - loss: 9.5848e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9933
# Epoch 30/40
# 38/38 [==============================] - 95s 2s/step - loss: 0.0066 - accuracy: 0.9967 - val_loss: 0.0229 - val_accuracy: 0.9933
# Epoch 31/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0820 - accuracy: 0.9833 - val_loss: 0.2283 - val_accuracy: 0.9195
# Epoch 32/40
# 38/38 [==============================] - 100s 3s/step - loss: 0.0179 - accuracy: 0.9916 - val_loss: 0.0610 - val_accuracy: 0.9732
# Epoch 33/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.0701 - val_accuracy: 0.9732
# Epoch 34/40
# 38/38 [==============================] - 92s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9799
# Epoch 35/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0465 - val_accuracy: 0.9866
# Epoch 36/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0424 - accuracy: 0.9883 - val_loss: 0.0565 - val_accuracy: 0.9732
# Epoch 37/40
# 38/38 [==============================] - 110s 3s/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0460 - val_accuracy: 0.9866
# Epoch 38/40
# 38/38 [==============================] - 104s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9866
# Epoch 39/40
# 38/38 [==============================] - 105s 3s/step - loss: 9.9027e-04 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9866
# Epoch 40/40
# 38/38 [==============================] - 98s 3s/step - loss: 6.2898e-04 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9933
# 5/5 [==============================] - 2s 443ms/step
# Cross-validation Accuracy: [0.699999988079071, 0.9599999785423279, 0.9798657894134521, 0.9865771532058716, 0.9932885766029358]
# Average Accuracy: 0.9239462971687317
# Std Accuracy: 0.11252535958925362
#
# Cross-validation Loss: [1.3289682865142822, 0.10483995825052261, 0.06563929468393326, 0.07247686386108398, 0.029308849945664406]
# Average Loss: 0.3202466506510973
# Std Loss: 0.5049314723063574
#
# Cross-validation AUC: [0.7224025974025973, 0.9575952764358562, 0.98125, 0.9865620490620491, 0.9929577464788732]
# Average AUC: 0.9281535338758753
# Std AUC: 0.10356702119576236
#
# Cross-validation F1-score: [0.6666666666666666, 0.963855421686747, 0.9808917197452229, 0.987012987012987, 0.9936305732484076]
# Average F1-score: 0.9184114736720062
# Std F1 score: 0.12626041500680188
#
# Cross-validation precision: [0.8823529411764706, 0.9411764705882353, 1.0, 0.987012987012987, 0.9873417721518988]
# Average Precision: 0.9595768341859182
# Std Precision: 0.043496596714454175
#
# Cross-validation Recall: [0.5357142857142857, 0.9876543209876543, 0.9625, 0.987012987012987, 1.0]
# Average Recall: 0.8945763187429854
# Std Recall: 0.17984314829177875
#
# Cross-validation Specificity: [0.9090909090909091, 0.927536231884058, 1.0, 0.9861111111111112, 0.9859154929577465]
# Average Specificity: 0.9617307490087649
# Std Specificity: 0.03628789664755684
#
# Fold Runtimes (seconds): [3472.6757724285126, 4953.750333070755, 4166.53106546402, 3827.8598551750183, 3905.0777912139893]
# Average Runtime: 4065.178963470459
# Standard Deviation of Runtimes: 496.5569661915513

# %%
import time

# Lists to store running times for each fold
fold_runtimes = []


n_folds = 5 
kf = KFold(n_splits=5, shuffle=True, random_state=10)

accuracies = []
losses = []
auc_scores = []
f1_scores = []
precision_scores = []
recall_scores = []
specificity_scores = []
mean_fpr = np.linspace(0, 1, 100)
tprs = []
confusion_matrices=[]

# Initialize dictionaries to store metrics for each class across folds
class_metrics = {metric: {} for metric in ['precision', 'recall', 'f1-score', 'support', 'specificity']}


# Lists to store metrics for each fold
all_train_accuracy = []
all_val_accuracy = []
all_train_loss = []
all_val_loss = []

train_images = x_train
train_labels = y_train


for fold, (train_index, val_index) in enumerate(kf.split(train_images)):
    print(f"Training on Fold {fold + 1}...")
    start_time = time.time() 
#for train_index, val_index in kf.split(train_images):
    # Split data into training and validation sets
    X_train_fold, X_val_fold = train_images[train_index], train_images[val_index]
    y_train_fold, y_val_fold = train_labels[train_index], train_labels[val_index]
    
    # Train the model on the training data
    history = model.fit(X_train_fold, y_train_fold, epochs=40, batch_size=16,validation_data=(X_val_fold, y_val_fold), verbose=1)
    
    
    end_time = time.time()  # Record end time
    fold_runtime = end_time - start_time  # Calculate duration
    fold_runtimes.append(fold_runtime)  # Store duration for this fold
    
         # Collect training history for accuracy and loss
    train_accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    
#     train_accuracy = history.history['binary_accuracy']
#     val_accuracy = history.history['val_binary_accuracy']
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
     # Append the metrics for this fold to the lists
    all_train_accuracy.append(train_accuracy)
    all_val_accuracy.append(val_accuracy)
    all_train_loss.append(train_loss)
    all_val_loss.append(val_loss)

    
    # Evaluate the model on the test set for this fold
    test_loss, test_accuracy = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    accuracies.append(test_accuracy)
    losses.append(test_loss)
    
    
    
    # Evaluate the model on the validation data
    val_preds = model.predict(X_val_fold)
    val_acc = accuracy_score(np.argmax(y_val_fold, axis=1), np.argmax(val_preds, axis=1))
    
    
    auc_score = roc_auc_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    auc_scores.append(auc_score)
    
    f1 = f1_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    f1_scores.append(f1)
    
    precision = precision_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    precision_scores.append(precision)
    
    recall = recall_score(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    recall_scores.append(recall)
    
    
    cm = confusion_matrix(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    print(cm)
    confusion_matrices.append(cm)

     # Calculate specificity
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)
    specificity_scores.append(specificity)
    

    # Generate classification report for detailed metrics
    report = classification_report(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1), output_dict=True)
    
    print(report)
    for cls, metrics in report.items():
        if cls.isdigit():  # Ensure the key is a class (digits)
            if cls not in class_metrics['precision']:
                for metric in class_metrics:
                    class_metrics[metric][cls] = []
            class_metrics['precision'][cls].append(metrics['precision'])
            class_metrics['recall'][cls].append(metrics['recall'])
            class_metrics['f1-score'][cls].append(metrics['f1-score'])
            class_metrics['support'][cls].append(metrics['support'])

    # Calculate specificity for each class and add to class metrics
    for i in range(len(cm)):
        tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fp = cm[:, i].sum() - cm[i, i]
        specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
        class_metrics['specificity'].setdefault(str(i), []).append(specificity)
        
#     # Append validation accuracy to list
#     cv_scores.append(val_acc)
    
    

    # Calculate ROC curve for this fold and interpolate it to make it smoother
    fpr, tpr, _ = roc_curve(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1))
    tprs.append(np.interp(mean_fpr, fpr, tpr))

    # Plot the AUC-ROC curve for this fold
    #plt.plot(fpr, tpr, label=f'Fold {len(fold_scores)}')
    plt.plot(fpr, tpr, lw=1, alpha=0.7, label='Fold {} (AUC = {:.2f})'.format(fold, auc_score))
 
    
# Calculate and plot the mean ROC curve
mean_tpr = np.mean(tprs, axis=0)
mean_auc = auc(mean_fpr, mean_tpr)

# Optionally, plot the mean ROC curve
plt.plot(mean_fpr, mean_tpr, color='b', lw=2, label='Mean ROC (AUC = {:.2f})'.format(mean_auc))
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

# Optionally, configure the plot for the ROC curve
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Mean ROC Curve')
plt.legend(loc='lower right')
plt.show()
    
# # Print cross-validation scores
# print("Cross-Validation Scores:", cv_scores)
# print("Mean CV Score:", np.mean(cv_scores))
# print("Standard Deviation of CV Scores:", np.std(cv_scores))


print("Cross-validation Accuracy:", accuracies)
print("Average Accuracy:", np.mean(accuracies))
print("Std Accuracy:", np.std(accuracies))
print()
print("Cross-validation Loss:", losses)
print("Average Loss:", np.mean(losses))
print("Std Loss:", np.std(losses))
print()
print("Cross-validation AUC:", auc_scores)
print("Average AUC:", np.mean(auc_scores))
print("Std AUC:", np.std(auc_scores))
print()
print("Cross-validation F1-score:", f1_scores)
print("Average F1-score:", np.mean(f1_scores))
print("Std F1 score:", np.std(f1_scores))
print()
print("Cross-validation precision:", precision_scores)
print("Average Precision:", np.mean(precision_scores))
print("Std Precision:", np.std(precision_scores))
print()
print("Cross-validation Recall:", recall_scores)
print("Average Recall:", np.mean(recall_scores))
print("Std Recall:", np.std(recall_scores))
print()
print("Cross-validation Specificity:", specificity_scores)
print("Average Specificity:", np.mean(specificity_scores))
print("Std Specificity:", np.std(specificity_scores))
print()
print("Fold Runtimes (seconds):", fold_runtimes)
print("Average Runtime:", np.mean(fold_runtimes))
print("Standard Deviation of Runtimes:", np.std(fold_runtimes))
# Out:
# Training on Fold 1...
# Epoch 1/40
# 38/38 [==============================] - 132s 3s/step - loss: 0.6369 - accuracy: 0.6533 - val_loss: 0.7081 - val_accuracy: 0.5600
# Epoch 2/40
# 38/38 [==============================] - 109s 3s/step - loss: 0.4066 - accuracy: 0.8040 - val_loss: 0.9039 - val_accuracy: 0.6000
# Epoch 3/40
# 38/38 [==============================] - 129s 3s/step - loss: 0.2695 - accuracy: 0.8945 - val_loss: 2.2320 - val_accuracy: 0.4533
# Epoch 4/40
# 38/38 [==============================] - 142s 4s/step - loss: 0.1957 - accuracy: 0.9213 - val_loss: 2.8670 - val_accuracy: 0.5200
# Epoch 5/40
# 38/38 [==============================] - 107s 3s/step - loss: 0.2036 - accuracy: 0.9095 - val_loss: 0.8444 - val_accuracy: 0.7333
# Epoch 6/40
# 38/38 [==============================] - 131s 3s/step - loss: 0.2005 - accuracy: 0.9229 - val_loss: 0.6280 - val_accuracy: 0.7533
# Epoch 7/40
# 38/38 [==============================] - 123s 3s/step - loss: 0.1196 - accuracy: 0.9564 - val_loss: 1.5690 - val_accuracy: 0.6667
# Epoch 8/40
# 38/38 [==============================] - 100s 3s/step - loss: 0.2532 - accuracy: 0.8894 - val_loss: 0.9996 - val_accuracy: 0.7400
# Epoch 9/40
# 38/38 [==============================] - 122s 3s/step - loss: 0.1640 - accuracy: 0.9347 - val_loss: 1.4929 - val_accuracy: 0.6333
# Epoch 10/40
# 38/38 [==============================] - 126s 3s/step - loss: 0.0810 - accuracy: 0.9749 - val_loss: 0.6723 - val_accuracy: 0.7867
# Epoch 11/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0809 - accuracy: 0.9782 - val_loss: 0.6685 - val_accuracy: 0.7800
# Epoch 12/40
# 38/38 [==============================] - 119s 3s/step - loss: 0.0703 - accuracy: 0.9765 - val_loss: 0.5685 - val_accuracy: 0.8000
# Epoch 13/40
# 38/38 [==============================] - 130s 3s/step - loss: 0.0728 - accuracy: 0.9799 - val_loss: 0.8042 - val_accuracy: 0.7800
# Epoch 14/40
# 38/38 [==============================] - 89s 2s/step - loss: 0.1833 - accuracy: 0.9380 - val_loss: 1.2601 - val_accuracy: 0.7133
# Epoch 15/40
# 38/38 [==============================] - 115s 3s/step - loss: 0.1094 - accuracy: 0.9581 - val_loss: 1.8894 - val_accuracy: 0.6333
# Epoch 16/40
# 38/38 [==============================] - 137s 4s/step - loss: 0.0538 - accuracy: 0.9799 - val_loss: 1.0152 - val_accuracy: 0.7667
# Epoch 17/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0269 - accuracy: 0.9916 - val_loss: 0.4812 - val_accuracy: 0.8133
# Epoch 18/40
# 38/38 [==============================] - 115s 3s/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 0.7029 - val_accuracy: 0.7733
# Epoch 19/40
# 38/38 [==============================] - 144s 4s/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.5720 - val_accuracy: 0.8067
# Epoch 20/40
# 38/38 [==============================] - 110s 3s/step - loss: 0.0447 - accuracy: 0.9749 - val_loss: 0.5696 - val_accuracy: 0.8133
# Epoch 22/40
# 38/38 [==============================] - 138s 4s/step - loss: 0.2177 - accuracy: 0.9179 - val_loss: 1.1920 - val_accuracy: 0.6533
# Epoch 23/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.1685 - accuracy: 0.9347 - val_loss: 0.8772 - val_accuracy: 0.7600
# Epoch 24/40
# 38/38 [==============================] - 106s 3s/step - loss: 0.0958 - accuracy: 0.9631 - val_loss: 0.7606 - val_accuracy: 0.7667
# Epoch 25/40
# 38/38 [==============================] - 140s 4s/step - loss: 0.0392 - accuracy: 0.9899 - val_loss: 0.6136 - val_accuracy: 0.8067
# Epoch 26/40
# 38/38 [==============================] - 106s 3s/step - loss: 0.0248 - accuracy: 0.9933 - val_loss: 0.7302 - val_accuracy: 0.7667
# Epoch 27/40
# 38/38 [==============================] - 110s 3s/step - loss: 0.0313 - accuracy: 0.9916 - val_loss: 0.6737 - val_accuracy: 0.7800
# Epoch 28/40
# 38/38 [==============================] - 141s 4s/step - loss: 0.0213 - accuracy: 0.9933 - val_loss: 0.8158 - val_accuracy: 0.7867
# Epoch 29/40
# 38/38 [==============================] - 105s 3s/step - loss: 0.1019 - accuracy: 0.9682 - val_loss: 1.9006 - val_accuracy: 0.6467
# Epoch 30/40
# 38/38 [==============================] - 104s 3s/step - loss: 0.0986 - accuracy: 0.9665 - val_loss: 1.0236 - val_accuracy: 0.7467
# Epoch 31/40
# 38/38 [==============================] - 128s 3s/step - loss: 0.0625 - accuracy: 0.9799 - val_loss: 0.9566 - val_accuracy: 0.7400
# Epoch 32/40
# 38/38 [==============================] - 113s 3s/step - loss: 0.0866 - accuracy: 0.9665 - val_loss: 0.9660 - val_accuracy: 0.7533
# Epoch 33/40
# 38/38 [==============================] - 107s 3s/step - loss: 0.0419 - accuracy: 0.9866 - val_loss: 1.6540 - val_accuracy: 0.7067
# Epoch 34/40
# 38/38 [==============================] - 127s 3s/step - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.9130 - val_accuracy: 0.7667
# Epoch 35/40
# 38/38 [==============================] - 119s 3s/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.7242 - val_accuracy: 0.7200
# Epoch 36/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0191 - accuracy: 0.9899 - val_loss: 1.3678 - val_accuracy: 0.6867
# Epoch 37/40
# 38/38 [==============================] - 125s 3s/step - loss: 0.0265 - accuracy: 0.9933 - val_loss: 0.6784 - val_accuracy: 0.8067
# Epoch 38/40
# 38/38 [==============================] - 126s 3s/step - loss: 0.0547 - accuracy: 0.9799 - val_loss: 0.8216 - val_accuracy: 0.7467
# Epoch 39/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0821 - accuracy: 0.9715 - val_loss: 1.8990 - val_accuracy: 0.6867
# Epoch 40/40
# 38/38 [==============================] - 123s 3s/step - loss: 0.0966 - accuracy: 0.9648 - val_loss: 0.6746 - val_accuracy: 0.7533
# 5/5 [==============================] - 10s 569ms/step
# [[55 11]
#  [26 58]]
# {'0': {'precision': 0.6790123456790124, 'recall': 0.8333333333333334, 'f1-score': 0.7482993197278912, 'support': 66.0}, '1': {'precision': 0.8405797101449275, 'recall': 0.6904761904761905, 'f1-score': 0.7581699346405228, 'support': 84.0}, 'accuracy': 0.7533333333333333, 'macro avg': {'precision': 0.75979602791197, 'recall': 0.7619047619047619, 'f1-score': 0.753234627184207, 'support': 150.0}, 'weighted avg': {'precision': 0.7694900697799247, 'recall': 0.7533333333333333, 'f1-score': 0.7538268640789649, 'support': 150.0}}
# Training on Fold 2...
# Epoch 1/40
# 38/38 [==============================] - 125s 3s/step - loss: 0.2621 - accuracy: 0.9095 - val_loss: 0.3957 - val_accuracy: 0.8067
# Epoch 2/40
# 38/38 [==============================] - 103s 3s/step - loss: 0.0962 - accuracy: 0.9732 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 3/40
# 38/38 [==============================] - 124s 3s/step - loss: 0.0400 - accuracy: 0.9899 - val_loss: 0.0260 - val_accuracy: 0.9933
# Epoch 4/40
# 38/38 [==============================] - 124s 3s/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0264 - val_accuracy: 0.9933
# Epoch 5/40
# 38/38 [==============================] - 94s 2s/step - loss: 0.0116 - accuracy: 0.9983 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 6/40
# 38/38 [==============================] - 124s 3s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 7/40
# 38/38 [==============================] - 128s 3s/step - loss: 0.0300 - accuracy: 0.9883 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 8/40
# 38/38 [==============================] - 104s 3s/step - loss: 0.0313 - accuracy: 0.9899 - val_loss: 0.2193 - val_accuracy: 0.9400
# Epoch 9/40
# 38/38 [==============================] - 125s 3s/step - loss: 0.0508 - accuracy: 0.9849 - val_loss: 0.2204 - val_accuracy: 0.9133
# Epoch 10/40
# 38/38 [==============================] - 127s 3s/step - loss: 0.0157 - accuracy: 0.9966 - val_loss: 0.2512 - val_accuracy: 0.9267
# Epoch 11/40
# 38/38 [==============================] - 91s 2s/step - loss: 0.0367 - accuracy: 0.9916 - val_loss: 0.1081 - val_accuracy: 0.9733
# Epoch 12/40
# 38/38 [==============================] - 105s 3s/step - loss: 0.0982 - accuracy: 0.9715 - val_loss: 0.1423 - val_accuracy: 0.9533
# Epoch 13/40
# 38/38 [==============================] - 142s 4s/step - loss: 0.2258 - accuracy: 0.9196 - val_loss: 0.8765 - val_accuracy: 0.7600
# Epoch 14/40
# 38/38 [==============================] - 99s 3s/step - loss: 0.1411 - accuracy: 0.9548 - val_loss: 0.1056 - val_accuracy: 0.9533
# Epoch 15/40
# 38/38 [==============================] - 104s 3s/step - loss: 0.0436 - accuracy: 0.9832 - val_loss: 0.4520 - val_accuracy: 0.8333
# Epoch 16/40
# 38/38 [==============================] - 144s 4s/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.0682 - val_accuracy: 0.9733
# Epoch 17/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.3209 - val_accuracy: 0.8867
# Epoch 18/40
# 38/38 [==============================] - 112s 3s/step - loss: 0.0108 - accuracy: 0.9983 - val_loss: 0.0684 - val_accuracy: 0.9667
# Epoch 19/40
# 38/38 [==============================] - 143s 4s/step - loss: 0.0184 - accuracy: 0.9933 - val_loss: 0.0706 - val_accuracy: 0.9667
# Epoch 20/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0903 - accuracy: 0.9715 - val_loss: 0.1198 - val_accuracy: 0.9533
# Epoch 21/40
# 38/38 [==============================] - 110s 3s/step - loss: 0.0235 - accuracy: 0.9983 - val_loss: 0.1788 - val_accuracy: 0.9467
# Epoch 22/40
# 38/38 [==============================] - 104s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9733
# Epoch 24/40
# 38/38 [==============================] - 112s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0520 - val_accuracy: 0.9867
# Epoch 25/40
# 38/38 [==============================] - 126s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9867
# Epoch 26/40
# 38/38 [==============================] - 112s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0512 - val_accuracy: 0.9933
# Epoch 27/40
# 38/38 [==============================] - 105s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9867
# Epoch 28/40
# 38/38 [==============================] - 130s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0807 - val_accuracy: 0.9533
# Epoch 29/40
# 38/38 [==============================] - 115s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9733
# Epoch 30/40
# 38/38 [==============================] - 100s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9733
# Epoch 31/40
# 38/38 [==============================] - 136s 4s/step - loss: 8.2504e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9733
# Epoch 32/40
# 38/38 [==============================] - 103s 3s/step - loss: 9.6280e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9800
# Epoch 34/40
# 38/38 [==============================] - 134s 4s/step - loss: 0.0072 - accuracy: 0.9966 - val_loss: 0.0917 - val_accuracy: 0.9600
# Epoch 35/40
# 38/38 [==============================] - 119s 3s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9800
# Epoch 36/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.1004 - val_accuracy: 0.9667
# Epoch 37/40
# 38/38 [==============================] - 120s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 0.9800
# Epoch 38/40
# 38/38 [==============================] - 124s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9867
# Epoch 39/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9867
# Epoch 40/40
# 38/38 [==============================] - 128s 3s/step - loss: 0.0265 - accuracy: 0.9933 - val_loss: 0.0123 - val_accuracy: 0.9933
# Epoch 2/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0224 - accuracy: 0.9950 - val_loss: 0.0611 - val_accuracy: 0.9799
# Epoch 3/40
# 38/38 [==============================] - 116s 3s/step - loss: 0.0631 - accuracy: 0.9783 - val_loss: 0.0462 - val_accuracy: 0.9866
# Epoch 4/40
# 38/38 [==============================] - 131s 3s/step - loss: 0.0703 - accuracy: 0.9799 - val_loss: 0.0171 - val_accuracy: 0.9933
# Epoch 5/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0690 - accuracy: 0.9732 - val_loss: 0.0392 - val_accuracy: 0.9866
# Epoch 6/40
# 38/38 [==============================] - 110s 3s/step - loss: 0.0908 - accuracy: 0.9699 - val_loss: 0.0765 - val_accuracy: 0.9664
# Epoch 7/40
# 38/38 [==============================] - 137s 4s/step - loss: 0.0537 - accuracy: 0.9866 - val_loss: 0.1308 - val_accuracy: 0.9530
# Epoch 8/40
# 38/38 [==============================] - 113s 3s/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.0669 - val_accuracy: 0.9799
# Epoch 13/40
# 38/38 [==============================] - 136s 4s/step - loss: 0.0353 - accuracy: 0.9866 - val_loss: 0.0344 - val_accuracy: 0.9933
# Epoch 14/40
# 38/38 [==============================] - 100s 3s/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0372 - val_accuracy: 0.9866
# Epoch 15/40
# 38/38 [==============================] - 107s 3s/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 16/40
# 38/38 [==============================] - 109s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9732
# Epoch 18/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0033 - accuracy: 0.9983 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 19/40
# 38/38 [==============================] - 132s 4s/step - loss: 0.0081 - accuracy: 0.9967 - val_loss: 0.0347 - val_accuracy: 0.9866
# Epoch 20/40
# 38/38 [==============================] - 116s 3s/step - loss: 0.0138 - accuracy: 0.9967 - val_loss: 0.0290 - val_accuracy: 0.9866
# Epoch 21/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0716 - val_accuracy: 0.9799
# Epoch 22/40
# 38/38 [==============================] - 132s 3s/step - loss: 0.0193 - accuracy: 0.9916 - val_loss: 0.1395 - val_accuracy: 0.9597
# Epoch 23/40
# 38/38 [==============================] - 116s 3s/step - loss: 0.0323 - accuracy: 0.9883 - val_loss: 0.0457 - val_accuracy: 0.9732
# Epoch 24/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0932 - val_accuracy: 0.9732
# Epoch 25/40
# 38/38 [==============================] - 109s 3s/step - loss: 0.0122 - accuracy: 0.9983 - val_loss: 0.0618 - val_accuracy: 0.9664
# Epoch 26/40
# 38/38 [==============================] - 100s 3s/step - loss: 0.0884 - accuracy: 0.9682 - val_loss: 0.3950 - val_accuracy: 0.8926
# Epoch 28/40
# 38/38 [==============================] - 120s 3s/step - loss: 0.0427 - accuracy: 0.9799 - val_loss: 0.3538 - val_accuracy: 0.9195
# Epoch 29/40
# 38/38 [==============================] - 132s 3s/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 0.1897 - val_accuracy: 0.9396
# Epoch 30/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.0821 - val_accuracy: 0.9732
# Epoch 31/40
# 38/38 [==============================] - 110s 3s/step - loss: 0.0112 - accuracy: 0.9950 - val_loss: 0.1130 - val_accuracy: 0.9597
# Epoch 32/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0619 - accuracy: 0.9749 - val_loss: 0.1263 - val_accuracy: 0.9396
# Epoch 34/40
# 38/38 [==============================] - 113s 3s/step - loss: 0.0143 - accuracy: 0.9967 - val_loss: 0.0676 - val_accuracy: 0.9530
# Epoch 35/40
# 38/38 [==============================] - 138s 4s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9866
# Epoch 36/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9799
# Epoch 37/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0088 - accuracy: 0.9983 - val_loss: 0.0709 - val_accuracy: 0.9732
# Epoch 38/40
# 38/38 [==============================] - 116s 3s/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.1077 - val_accuracy: 0.9463
# Epoch 39/40
# 38/38 [==============================] - 70s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9799
# 5/5 [==============================] - 2s 338ms/step
# [[67  2]
#  [ 1 79]]
# {'0': {'precision': 0.9852941176470589, 'recall': 0.9710144927536232, 'f1-score': 0.9781021897810219, 'support': 69.0}, '1': {'precision': 0.9753086419753086, 'recall': 0.9875, 'f1-score': 0.9813664596273292, 'support': 80.0}, 'accuracy': 0.9798657718120806, 'macro avg': {'precision': 0.9803013798111837, 'recall': 0.9792572463768117, 'f1-score': 0.9797343247041755, 'support': 149.0}, 'weighted avg': {'precision': 0.9799327884273272, 'recall': 0.9798657718120806, 'f1-score': 0.9798548178864217, 'support': 149.0}}
# Training on Fold 4...
# Epoch 1/40
# 38/38 [==============================] - 89s 2s/step - loss: 0.0324 - accuracy: 0.9883 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 2/40
# 38/38 [==============================] - 111s 3s/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 3/40
# 38/38 [==============================] - 98s 3s/step - loss: 0.0293 - accuracy: 0.9866 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 4/40
# 38/38 [==============================] - 89s 2s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 5/40
# 38/38 [==============================] - 99s 3s/step - loss: 0.0524 - accuracy: 0.9816 - val_loss: 0.1332 - val_accuracy: 0.9664
# Epoch 6/40
# 38/38 [==============================] - 114s 3s/step - loss: 0.0377 - accuracy: 0.9816 - val_loss: 0.0292 - val_accuracy: 0.9866
# Epoch 7/40
# 38/38 [==============================] - 91s 2s/step - loss: 0.0084 - accuracy: 0.9983 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 8/40
# 38/38 [==============================] - 103s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 6.9868e-04 - val_accuracy: 1.0000
# Epoch 10/40
# 38/38 [==============================] - 108s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.8537e-04 - val_accuracy: 1.0000
# Epoch 11/40
# 38/38 [==============================] - 83s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 12/40
# 38/38 [==============================] - 92s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 13/40
# 38/38 [==============================] - 108s 3s/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 14/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 15/40
# 38/38 [==============================] - 88s 2s/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 16/40
# 38/38 [==============================] - 116s 3s/step - loss: 0.0651 - accuracy: 0.9883 - val_loss: 0.0688 - val_accuracy: 0.9664
# Epoch 29/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0163 - accuracy: 0.9967 - val_loss: 0.0832 - val_accuracy: 0.9597
# Epoch 30/40
# 38/38 [==============================] - 92s 2s/step - loss: 0.0254 - accuracy: 0.9900 - val_loss: 0.1588 - val_accuracy: 0.9664
# Epoch 31/40
# 38/38 [==============================] - 101s 3s/step - loss: 0.0210 - accuracy: 0.9916 - val_loss: 0.0854 - val_accuracy: 0.9732
# Epoch 32/40
# 38/38 [==============================] - 109s 3s/step - loss: 0.0289 - accuracy: 0.9900 - val_loss: 0.0436 - val_accuracy: 0.9799
# Epoch 33/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0234 - accuracy: 0.9916 - val_loss: 0.0745 - val_accuracy: 0.9597
# Epoch 34/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9933
# Epoch 35/40
# 38/38 [==============================] - 116s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 0.9933
# Epoch 36/40
# 38/38 [==============================] - 84s 2s/step - loss: 5.7534e-04 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# 5/5 [==============================] - 1s 290ms/step
# [[72  0]
#  [ 0 77]]
# {'0': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 72.0}, '1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 77.0}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 149.0}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 149.0}}
# Training on Fold 5...
# Epoch 1/40
# 38/38 [==============================] - 92s 2s/step - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0486 - val_accuracy: 0.9799
# Epoch 2/40
# 38/38 [==============================] - 104s 3s/step - loss: 0.0880 - accuracy: 0.9732 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 3/40
# 38/38 [==============================] - 102s 3s/step - loss: 0.0349 - accuracy: 0.9900 - val_loss: 0.0191 - val_accuracy: 0.9933
# Epoch 4/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0227 - accuracy: 0.9916 - val_loss: 0.0497 - val_accuracy: 0.9866
# Epoch 5/40
# 38/38 [==============================] - 97s 3s/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 0.0173 - val_accuracy: 0.9933
# Epoch 6/40
# 38/38 [==============================] - 108s 3s/step - loss: 0.0550 - accuracy: 0.9783 - val_loss: 0.1358 - val_accuracy: 0.9396
# 38/38 [==============================] - 92s 2s/step - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.0456 - val_accuracy: 0.9866
# Epoch 27/40
# 38/38 [==============================] - 87s 2s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9933
# Epoch 28/40
# 38/38 [==============================] - 105s 3s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9933
# Epoch 29/40
# 38/38 [==============================] - 113s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 30/40
# 38/38 [==============================] - 81s 2s/step - loss: 3.4442e-04 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 31/40
# 38/38 [==============================] - 92s 2s/step - loss: 9.7116e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 32/40
# 38/38 [==============================] - 102s 3s/step - loss: 3.0680e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 33/40
# 38/38 [==============================] - 106s 3s/step - loss: 3.2043e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 34/40
# 38/38 [==============================] - 85s 2s/step - loss: 5.5039e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 35/40
# 38/38 [==============================] - 102s 3s/step - loss: 2.1847e-04 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 36/40
# 38/38 [==============================] - 124s 3s/step - loss: 4.4960e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 37/40
# 38/38 [==============================] - 89s 2s/step - loss: 7.9239e-04 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9933
# Epoch 38/40
# 38/38 [==============================] - 88s 2s/step - loss: 6.0700e-04 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9933
# Epoch 39/40
# 38/38 [==============================] - 105s 3s/step - loss: 6.5201e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 40/40
# 38/38 [==============================] - 109s 3s/step - loss: 2.4739e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# 5/5 [==============================] - 1s 290ms/step
# [[71  0]
#  [ 0 78]]
# {'0': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 71.0}, '1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 78.0}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 149.0}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 149.0}}
# Cross-validation Accuracy: [0.753333330154419, 0.9866666793823242, 0.9798657894134521, 1.0, 1.0]
# Average Accuracy: 0.943973159790039
# Std Accuracy: 0.09563741502966672
#
# Cross-validation Loss: [0.6746376752853394, 0.04007929563522339, 0.09133043885231018, 0.006075253710150719, 0.004597508814185858]
# Average Loss: 0.1633440344594419
# Std Loss: 0.2575792187819043
#
# Cross-validation AUC: [0.761904761904762, 0.9865807836822329, 0.9792572463768116, 1.0, 1.0]
# Average AUC: 0.9455485583927612
# Std AUC: 0.09216819639393056
#
# Cross-validation F1-score: [0.7581699346405228, 0.9876543209876543, 0.9813664596273292, 1.0, 1.0]
# Average F1-score: 0.9454381430511013
# Std F1 score: 0.09391104723120104
#
# Cross-validation precision: [0.8405797101449275, 0.9876543209876543, 0.9753086419753086, 1.0, 1.0]
# Average Precision: 0.9607085346215781
# Std Precision: 0.06075822826734837
#
# Cross-validation Recall: [0.6904761904761905, 0.9876543209876543, 0.9875, 1.0, 1.0]
# Average Recall: 0.9331261022927689
# Std Recall: 0.12145210041791898
#
# Cross-validation Specificity: [0.8333333333333334, 0.9855072463768116, 0.9710144927536232, 1.0, 1.0]
# Average Specificity: 0.9579710144927536
# Std Specificity: 0.0632389108094824
#
# Fold Runtimes (seconds): [4704.3424072265625, 4659.383450984955, 4517.262967586517, 3927.6936287879944, 3895.5553817749023]
# Average Runtime: 4340.847567272186
# Standard Deviation of Runtimes: 356.00486196234584

# %%
for metric in class_metrics:
    if metric != 'specificity':  # Specificity already printed
        print(f"Cross-validation {metric} per class:")
        for cls, values in class_metrics[metric].items():
            print(f"Class {cls}: {np.mean(values):.4f} ± {np.std(values):.4f}")
# Out:
# Cross-validation precision per class:
# Class 0: 0.9300 ± 0.1256
# Class 1: 0.9607 ± 0.0608
# Cross-validation recall per class:
# Class 0: 0.9580 ± 0.0632
# Class 1: 0.9331 ± 0.1215
# Cross-validation f1-score per class:
# Class 0: 0.9424 ± 0.0974
# Class 1: 0.9454 ± 0.0939
# Cross-validation support per class:
# Class 0: 69.4000 ± 2.0591
# Class 1: 80.0000 ± 2.4495

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Iterate through the confusion matrices for each fold
for fold_num, cm in enumerate(confusion_matrices, start=1):
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix - Fold {fold_num}")
    plt.show()

# %% [markdown]
# ### Evlaution on test set

# %%
start_time = time.time()
y_pred = model.predict(x_val)
# y_pred = model.predict(test_images)

end_time = time.time()
prediction_time = end_time - start_time
predd = np.argmax(y_pred, axis=1)  # Convert probabilities to class labels if needed



accuracy = accuracy_score(np.argmax(y_val, axis=1), predd)

# Compute F1 score
f1 = f1_score(np.argmax(y_val, axis=1), predd, average='weighted')

# Compute recall
recall = recall_score(np.argmax(y_val, axis=1), predd, average='weighted')
precision = precision_score(np.argmax(y_val, axis=1), predd, average='weighted')
#auc = roc_auc_score(np.argmax(y_val, axis=1), y_pred)
auc = roc_auc_score(y_val, y_pred, multi_class='ovr')
cm = confusion_matrix(np.argmax(y_val,axis=1),np.argmax(y_pred,axis=1))
tn, fp, fn, tp = cm.ravel()
specificity = tn / (tn + fp)

print("Accuray:", accuracy)
print("Precision:", precision)
print("AUC:", auc)
print("F1 Score:", f1)
print("Recall:", recall)
print("specificity:", specificity)
print("Prediction Time:", prediction_time, "seconds")
# Out:
# 6/6 [==============================] - 3s 456ms/step
# Accuray: 0.8128342245989305
# Precision: 0.8150988239778473
# AUC: 0.9225085910652921
# F1 Score: 0.812057804478003
# Recall: 0.8128342245989305
# specificity: 0.865979381443299
# Prediction Time: 3.012585401535034 seconds

# %%
#cm = confusion_matrix(np.argmax(test_labels,axis=1),predd)
cm = confusion_matrix(np.argmax(y_val,axis=1),predd)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title(f"Confusion Matrix - Testset")
plt.show()

# %%
from tensorflow.keras.models import load_model
model.save('mobileNetU.h5')

# %%
report = classification_report(np.argmax(y_val_fold,axis=1),np.argmax(val_preds,axis=1), output_dict=True)

# %%
print(report)
# Out:
# {'0': {'precision': 0.8974358974358975, 'recall': 0.5303030303030303, 'f1-score': 0.6666666666666666, 'support': 66.0}, '1': {'precision': 0.7207207207207207, 'recall': 0.9523809523809523, 'f1-score': 0.8205128205128205, 'support': 84.0}, 'accuracy': 0.7666666666666667, 'macro avg': {'precision': 0.8090783090783091, 'recall': 0.7413419913419913, 'f1-score': 0.7435897435897436, 'support': 150.0}, 'weighted avg': {'precision': 0.7984753984753985, 'recall': 0.7666666666666667, 'f1-score': 0.7528205128205128, 'support': 150.0}}
